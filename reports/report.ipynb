# %%
# 📌 Purpose:
# This notebook summarizes the Investor Risk Profile project, including modeling, SHAP explanations,
# and clustering visualizations. It is designed to be exported to PDF for portfolio sharing.

import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import Image, display, Markdown
import os


display(Markdown("# Investor Risk Analysis & Profiling"))
display(Markdown("**Author:** Melek Ikiz"))
display(Markdown("**Date:** 2025-11-28"))
display(Markdown("**Objective:** Predict investor risk profiles and assign users to behavioral clusters."))


display(Markdown("## Features Used in Modeling"))

features = [
    "age", "income", "experience_years", "risk_survey_score",
    "total_transactions", "avg_amount", "active_days",
    "monthly_freq", "tx_count_30d",
    "pct_crypto", "pct_etf", "pct_forex", "pct_other",
    "pct_stocks", "pct_bond",
    "volatility_mean_30", "volatility_mean_60", "volatility_std_30"
]

display(Markdown("**Feature List:**"))
for f in features:
    display(Markdown(f"- {f}"))


display(Markdown("## Modeling Overview"))
display(Markdown("""
- Model: Random Forest Classifier
- Preprocessing: Scaling + Label Encoding
- Predicted risk levels: low, medium, high
- Performance charts: ROC, Confusion Matrix, Precision Recall (see performance_charts/)
"""))


display(Markdown("## SHAP Explanations"))

shap_images = [
    "../reports/shap_summary.png",
    "../reports/shap_summary_dot.png"
]

for img_path in shap_images:
    if os.path.exists(img_path):
        display(Image(img_path, width=600))
    else:
        display(Markdown(f" Image not found: {img_path}"))

display(Markdown("**Explanation:** SHAP values explain the model's prediction decisions. Global feature importance and example user contributions are illustrated."))


display(Markdown("## Clustering / Segmentation"))

cluster_images = [
    "../reports/cluster_distribution_pie.png",
    "../reports/cluster_pca_scatter.png",
    "../reports/cluster_elbow_method.png",
    "../reports/violin_total_transactions.png",
    "../reports/violin_avg_amount.png",
    "../reports/violin_monthly_freq.png",
    "../reports/violin_pct_crypto.png",
    "../reports/violin_pct_stocks.png"
]

for img_path in cluster_images:
    if os.path.exists(img_path):
        display(Image(img_path, width=600))
    else:
        display(Markdown(f" Image not found: {img_path}"))

display(Markdown("""
- Number of clusters: 3
- PCA visualization shows user segments.
- Cluster profile bar chart shows average feature values per cluster.
- Violin plots display distributions of key numeric features per cluster.
"""))


display(Markdown("## Insights / Business Notes"))
display(Markdown("""
- Cluster 1: Users with high transaction volume and medium risk tolerance.
- Top 5 SHAP features explain the model's risk prediction for each user.
- Cluster based analysis supports targeted strategies for user segments.
"""))

display(Markdown("## Conclusion & Recommendations"))
display(Markdown("""
- The demo enables visualization of user risk profiles and cluster segments.
- For production deployment, validate with larger, real world datasets.
- SHAP and cluster analysis can guide portfolio management and personalized investment advice.
"""))
# Out:
# # Investor Risk Analysis & Profiling
# **Author:** Melek Ikiz
# **Date:** 2025-11-28
# **Objective:** Predict investor risk profiles and assign users to behavioral clusters.
# ## Features Used in Modeling
# **Feature List:**
# - age
# - income
# - experience_years
# - risk_survey_score
# - total_transactions
# - avg_amount
# - active_days
# - monthly_freq
# - tx_count_30d
# - pct_crypto
# - pct_etf
# - pct_forex
# - pct_other
# - pct_stocks
# - pct_bond
# - volatility_mean_30
# - volatility_mean_60
# - volatility_std_30
# ## Modeling Overview
# - Model: Random Forest Classifier
# - Preprocessing: Scaling + Label Encoding
# - Predicted risk levels: low, medium, high
# - Performance charts: ROC, Confusion Matrix, Precision Recall (see performance_charts/)
# ## SHAP Explanations
# **Explanation:** SHAP values explain the model's prediction decisions. Global feature importance and example user contributions are illustrated.
# ## Clustering / Segmentation
# - Number of clusters: 3
# ...
